# %%
import pandas as pd

# %% [markdown]
# #### Hoang's preliminary data exploration

# %%
movie_gross = pd.read_csv("data/bom.movie_gross.csv")

# %%
movie_gross
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
movie_gross = movie_gross.fillna(0)

# %%
movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
movie_gross.replace(',','', regex=True, inplace=True)

# %%
movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
movie_gross['foreign_gross'] = pd.to_numeric(movie_gross['foreign_gross'], downcast = 'float')

# %%
movie_gross.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year
# 0    652000000.0  2010
# 1    691299968.0  2010
# 2    664300032.0  2010
# 3    535700000.0  2010
# 4    513900000.0  2010

# %%
movie_gross['total_gross'] = movie_gross['domestic_gross'] + movie_gross['foreign_gross']

# %%
movie_gross_sorted = movie_gross.sort_values('total_gross', ascending = False)
movie_gross_sorted.head(10)
# Out:
#                                             title studio  domestic_gross  \
# 727                         Marvel's The Avengers     BV     623400000.0
# 1875                      Avengers: Age of Ultron     BV     459000000.0
# 3080                                Black Panther     BV     700100000.0
# 328   Harry Potter and the Deathly Hallows Part 2     WB     381000000.0
# 2758                     Star Wars: The Last Jedi     BV     620200000.0
# 3081               Jurassic World: Fallen Kingdom   Uni.     417700000.0
# 1127                                       Frozen     BV     400700000.0
# 2759                  Beauty and the Beast (2017)     BV     504000000.0
# 3082                                Incredibles 2     BV     608600000.0
# 1128                                   Iron Man 3     BV     409000000.0
#
#       foreign_gross  year   total_gross
# 727     895500032.0  2012  1.518900e+09
# 1875    946400000.0  2015  1.405400e+09
# 3080    646899968.0  2018  1.347000e+09
# 328     960499968.0  2011  1.341500e+09
# 2758    712400000.0  2017  1.332600e+09
# 3081    891800000.0  2018  1.309500e+09
# 1127    875699968.0  2013  1.276400e+09
# 2759    759500032.0  2017  1.263500e+09
# 3082    634200000.0  2018  1.242800e+09
# 1128    805800000.0  2013  1.214800e+09

# %%
title_basics = pd.read_csv('data/title.basics.csv')

# %%
title_basics
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                   NaN
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
title_gross_movie = movie_gross.merge(title_basics, how = 'inner', left_on = "title", right_on = "primary_title" )

# %%
title_gross_movie_sorted = title_gross_movie.sort_values('total_gross', ascending = False)
title_gross_movie_sorted.head(10)
# Out:
#                                title studio  domestic_gross  foreign_gross  \
# 1790         Avengers: Age of Ultron     BV     459000000.0    946400000.0
# 3034                   Black Panther     BV     700100000.0    646899968.0
# 2686        Star Wars: The Last Jedi     BV     620200000.0    712400000.0
# 3035  Jurassic World: Fallen Kingdom   Uni.     417700000.0    891800000.0
# 1065                          Frozen     BV     400700000.0    875699968.0
# 1064                          Frozen     BV     400700000.0    875699968.0
# 1063                          Frozen     BV     400700000.0    875699968.0
# 3036                   Incredibles 2     BV     608600000.0    634200000.0
# 1066                      Iron Man 3     BV     409000000.0    805800000.0
# 1791                         Minions   Uni.     336000000.0    823400000.0
#
#       year   total_gross     tconst                   primary_title  \
# 1790  2015  1.405400e+09  tt2395427         Avengers: Age of Ultron
# 3034  2018  1.347000e+09  tt1825683                   Black Panther
# 2686  2017  1.332600e+09  tt2527336        Star Wars: The Last Jedi
# 3035  2018  1.309500e+09  tt4881806  Jurassic World: Fallen Kingdom
# 1065  2013  1.276400e+09  tt2294629                          Frozen
# 1064  2013  1.276400e+09  tt1611845                          Frozen
# 1063  2013  1.276400e+09  tt1323045                          Frozen
# 3036  2018  1.242800e+09  tt3606756                   Incredibles 2
# 1066  2013  1.214800e+09  tt1300854                      Iron Man 3
# 1791  2015  1.159400e+09  tt2293640                         Minions
#
#                                original_title  start_year  runtime_minutes  \
# 1790                  Avengers: Age of Ultron        2015            141.0
# 3034                            Black Panther        2018            134.0
# 2686  Star Wars: Episode VIII - The Last Jedi        2017            152.0
# 3035           Jurassic World: Fallen Kingdom        2018            128.0
# 1065                                   Frozen        2013            102.0
# 1064                      Wai nei chung ching        2010             92.0
# 1063                                   Frozen        2010             93.0
# 3036                            Incredibles 2        2018            118.0
# 1066                           Iron Man Three        2013            130.0
# 1791                                  Minions        2015             91.0
#
#                           genres
# 1790     Action,Adventure,Sci-Fi
# 3034     Action,Adventure,Sci-Fi
# 2686    Action,Adventure,Fantasy
# 3035     Action,Adventure,Sci-Fi
# 1065  Adventure,Animation,Comedy
# 1064             Fantasy,Romance
# 1063       Adventure,Drama,Sport
# 3036  Action,Adventure,Animation
# 1066     Action,Adventure,Sci-Fi
# 1791  Adventure,Animation,Comedy

# %% [markdown]
# #### Losing Values

# %%
title_ratings = pd.read_csv('data/title.ratings.csv')

# %%
title_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %%
title_ratings.head()
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
movie_title_gross_rating = title_gross_movie.merge(title_ratings, how = 'inner', on = "tconst" )

# %%
movie_title_gross_rating.head()
# Out:
#                         title studio  domestic_gross  foreign_gross  year  \
# 0                 Toy Story 3     BV     415000000.0    652000000.0  2010
# 1                   Inception     WB     292600000.0    535700000.0  2010
# 2         Shrek Forever After   P/DW     238700000.0    513900000.0  2010
# 3  The Twilight Saga: Eclipse   Sum.     300500000.0    398000000.0  2010
# 4                  Iron Man 2   Par.     312400000.0    311500000.0  2010
#
#     total_gross     tconst               primary_title  \
# 0  1.067000e+09  tt0435761                 Toy Story 3
# 1  8.283000e+08  tt1375666                   Inception
# 2  7.526000e+08  tt0892791         Shrek Forever After
# 3  6.985000e+08  tt1325004  The Twilight Saga: Eclipse
# 4  6.239000e+08  tt1228705                  Iron Man 2
#
#                original_title  start_year  runtime_minutes  \
# 0                 Toy Story 3        2010            103.0
# 1                   Inception        2010            148.0
# 2         Shrek Forever After        2010             93.0
# 3  The Twilight Saga: Eclipse        2010            124.0
# 4                  Iron Man 2        2010            124.0
#
#                        genres  averagerating  numvotes
# 0  Adventure,Animation,Comedy            8.3    682218
# 1     Action,Adventure,Sci-Fi            8.8   1841066
# 2  Adventure,Animation,Comedy            6.3    167532
# 3     Adventure,Drama,Fantasy            5.0    211733
# 4     Action,Adventure,Sci-Fi            7.0    657690

# %%
movie_title_gross_rating_sorted = movie_title_gross_rating.sort_values('total_gross', ascending = False)
movie_title_gross_rating_sorted.head(10)
# Out:
#                                title studio  domestic_gross  foreign_gross  \
# 1601         Avengers: Age of Ultron     BV     459000000.0    946400000.0
# 2724                   Black Panther     BV     700100000.0    646899968.0
# 2412        Star Wars: The Last Jedi     BV     620200000.0    712400000.0
# 2725  Jurassic World: Fallen Kingdom   Uni.     417700000.0    891800000.0
# 941                           Frozen     BV     400700000.0    875699968.0
# 942                           Frozen     BV     400700000.0    875699968.0
# 943                           Frozen     BV     400700000.0    875699968.0
# 2726                   Incredibles 2     BV     608600000.0    634200000.0
# 944                       Iron Man 3     BV     409000000.0    805800000.0
# 1602                         Minions   Uni.     336000000.0    823400000.0
#
#       year   total_gross     tconst                   primary_title  \
# 1601  2015  1.405400e+09  tt2395427         Avengers: Age of Ultron
# 2724  2018  1.347000e+09  tt1825683                   Black Panther
# 2412  2017  1.332600e+09  tt2527336        Star Wars: The Last Jedi
# 2725  2018  1.309500e+09  tt4881806  Jurassic World: Fallen Kingdom
# 941   2013  1.276400e+09  tt1323045                          Frozen
# 942   2013  1.276400e+09  tt1611845                          Frozen
# 943   2013  1.276400e+09  tt2294629                          Frozen
# 2726  2018  1.242800e+09  tt3606756                   Incredibles 2
# 944   2013  1.214800e+09  tt1300854                      Iron Man 3
# 1602  2015  1.159400e+09  tt2293640                         Minions
#
#                                original_title  start_year  runtime_minutes  \
# 1601                  Avengers: Age of Ultron        2015            141.0
# 2724                            Black Panther        2018            134.0
# 2412  Star Wars: Episode VIII - The Last Jedi        2017            152.0
# 2725           Jurassic World: Fallen Kingdom        2018            128.0
# 941                                    Frozen        2010             93.0
# 942                       Wai nei chung ching        2010             92.0
# 943                                    Frozen        2013            102.0
# 2726                            Incredibles 2        2018            118.0
# 944                            Iron Man Three        2013            130.0
# 1602                                  Minions        2015             91.0
#
#                           genres  averagerating  numvotes
# 1601     Action,Adventure,Sci-Fi            7.3    665594
# 2724     Action,Adventure,Sci-Fi            7.3    516148
# 2412    Action,Adventure,Fantasy            7.1    462903
# 2725     Action,Adventure,Sci-Fi            6.2    219125
# 941        Adventure,Drama,Sport            6.2     62311
# 942              Fantasy,Romance            5.4        75
# 943   Adventure,Animation,Comedy            7.5    516998
# 2726  Action,Adventure,Animation            7.7    203510
# 944      Action,Adventure,Sci-Fi            7.2    692794
# 1602  Adventure,Animation,Comedy            6.4    193917

# %%
movie_title_gross_rating.plot.scatter('averagerating', 'total_gross')
# Out:
# <AxesSubplot:xlabel='averagerating', ylabel='total_gross'>

# %%
movie_title_gross_rating.plot.bar('genres', 'total_gross')
# Out:
# <AxesSubplot:xlabel='genres'>

# %%
movie_title_gross_rating.plot.scatter('start_year', 'total_gross')
# Out:
# <AxesSubplot:xlabel='start_year', ylabel='total_gross'>

# %%
movie_title_gross_rating.plot.scatter('runtime_minutes', 'total_gross')
# Out:
# <AxesSubplot:xlabel='runtime_minutes', ylabel='total_gross'>

# %%
movie_title_gross_rating.plot.scatter('numvotes', 'total_gross')
# Out:
# <AxesSubplot:xlabel='numvotes', ylabel='total_gross'>
